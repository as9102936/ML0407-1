# %%
# !pip install snownlp
from snownlp import SnowNLP
from snownlp import sentiment

text1 = '這部店影真心棒'
text2 = '這部電影超爛'

s1 = SnowNLP(text1)
s2 = SnowNLP(text2)

print(text1, s1.sentiments) 
print(text2, s2.sentiments)
# Out:
# ...
# 這部店影真心棒 1
# 這部電影超爛 1

# %%
# !python -V
# Out:
# Python 3.6.9

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------
# absl-py                  0.9.0
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   4.1.0
# asgiref                  3.2.7
# astor                    0.8.1
# astropy                  4.0.1.post1
# astunparse               1.6.3
# atari-py                 0.2.6
# atomicwrites             1.4.0
# attrs                    19.3.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.8.0
# backcall                 0.1.0
# beautifulsoup4           4.6.3
# bleach                   3.1.5
# blis                     0.4.1
# bokeh                    1.4.0
# boto                     2.49.0
# boto3                    1.13.13
# botocore                 1.16.13
# Bottleneck               1.3.2
# branca                   0.4.1
# bs4                      0.0.1
# CacheControl             0.12.6
# cachetools               3.1.1
# ...

# %%
# !pip install dnspython

# %%
# !pip install --upgrade dnspython
# Out:
# Requirement already up-to-date: dnspython in /usr/local/lib/python3.6/dist-packages (1.16.0)

# %%
import pymongo
import requests
from pymongo import MongoClient
import bs4
import pandas as pd
import dns

myclient = pymongo.MongoClient("mongodb+srv://yuehhung_hsieh:a25641850,@database-version1-eh1vv.gcp.mongodb.net/test?retryWrites=true&w=majority")

#連接Database 使用Database Project

mydb = myclient['Project']

#使永Column All

mycol = mydb["All"]

db = myclient.Project

#select the collection within the database
test = mydb.All

#convert entire collection to Pandas dataframe
test = pd.DataFrame(list(test.find()))

print(test)

TEST = test.to_csv("TEST.CSV",index=False)

#print(test["TEXT"][0])
# Out:
#                             _id SOURCE    BRAND  ... GOOD BAD SHARE_TIMES
# 0      5ecdde3b59b053f3692fd904  CK101     ASUS  ...    0   1
# 1      5ecdde3b59b053f3692fd905  CK101     ASUS  ...
# 2      5ecdde3b59b053f3692fd906  CK101     ASUS  ...
# 3      5ecdde3b59b053f3692fd907  CK101     ASUS  ...
# 4      5ecdde3b59b053f3692fd908  CK101     ASUS  ...
# ...                         ...    ...      ...  ...  ...  ..         ...
# 21005  5ecf8c134d223b06e49608ee     巴哈  SAMSUNG  ...    0   0         NaN
# 21006  5ecf8c134d223b06e49608ef     巴哈  SAMSUNG  ...    0   0         NaN
# 21007  5ecf8c134d223b06e49608f0     巴哈  SAMSUNG  ...    0   0         NaN
# 21008  5ecf8c134d223b06e49608f1     巴哈  SAMSUNG  ...    0   0         NaN
# 21009  5ecf8c134d223b06e49608f2     巴哈  SAMSUNG  ...    0   0         NaN
#
# [21010 rows x 12 columns]

# %%
from snownlp import SnowNLP
from snownlp import sentiment

f1 = open('./pos.csv', 'a+', encoding='utf-8')  # 存放正面  名字也可自定义哦
f2 = open('./neg.csv', 'a+', encoding='utf-8')  # 存放负面

x = []
for i in range(len(test["TEXT"])):
  text = test["TEXT"][i]
  text = str(text)
  try:
    s = SnowNLP(text)
    print(s.sentiments)
    x.append(s.sentiments)
  except ZeroDivisionError:
    x.append("0")
    print('Predefined: ZeroDivisionError!!', i)
  if s.sentiments < 0.3:
    print(i, '這是負面評價', s.sentiments)
    # 这段文本写入neg文件中
    f2.write(text)
    f2.write('\n')

  elif s.sentiments > 0.8:  # 可以自定义范围
    print(i, '這是正面評價', s.sentiments)
    # 这段文本写入pos文件中
    f1.write(text)
    f1.write('\n')
  else:
    print('這是普通評價')
  # 保存此次的训练模型
  sentiment.train(r'./neg.csv',r'./pos.csv')
# Out:
# 1
# 0 這是正面評價 1
# 1.0
# 1 這是正面評價 1.0
# 1.0
# 2 這是正面評價 1.0
# 1.0
# 3 這是正面評價 1.0
# 1.0
# 4 這是正面評價 1.0
# 1.0
# 5 這是正面評價 1.0
# 1.0
# 6 這是正面評價 1.0
# 1.0
# 7 這是正面評價 1.0
# 1.0
# 8 這是正面評價 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d8350d84cd55> in <module>()
#      30     print('這是普通評價')
#      31   # 保存此次的训练模型
# ---> 32   sentiment.train(r'./neg.csv',r'./pos.csv')
#
# /usr/local/lib/python3.6/dist-packages/snownlp/sentiment/__init__.py in train(neg_file, pos_file)
#      53     global classifier
#      54     classifier = Sentiment()
# ---> 55     classifier.train(neg_docs, pos_docs)
#      56
#      57
#
# /usr/local/lib/python3.6/dist-packages/snownlp/sentiment/__init__.py in train(self, neg_docs, pos_docs)
#      34             data.append([self.handle(sent), 'neg'])
#      35         for sent in pos_docs:
# ...
